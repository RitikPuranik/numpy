# %%
a = 12

# %%
print("hello")

# %%
def hello():
    print("how are you")

# %%
hello()

# %%
hello()

# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world
